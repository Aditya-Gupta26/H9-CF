# %%
import sys
# !{sys.executable} -m pip install Historic_Crypto
import pandas as pd
from Historic_Crypto import HistoricalData
btc_historicals = HistoricalData('BTC-USD',21600,'2017-04-02-00-00','2022-04-02-00-00').retrieve_data()
df = pd.DataFrame(btc_historicals)
df.to_csv('historicaldata.csv')
# Out:
# Collecting Historic_Crypto
#   Using cached Historic_Crypto-0.1.6-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from Historic_Crypto) (1.20.1)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from Historic_Crypto) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\dell\anaconda3\lib\site-packages (from requests->Historic_Crypto) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->Historic_Crypto) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->Historic_Crypto) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->Historic_Crypto) (2.10)
# Installing collected packages: Historic-Crypto
# Successfully installed Historic-Crypto-0.1.6
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2017-04-02T00:00:00
# Provisional End: 2017-06-16T00:00:00
# Data for chunk 1 of 25 extracted
# Provisional Start: 2017-06-16T00:00:00
# Provisional End: 2017-08-30T00:00:00
# Data for chunk 2 of 25 extracted
# Provisional Start: 2017-08-30T00:00:00
# Provisional End: 2017-11-13T00:00:00
# Data for chunk 3 of 25 extracted
# Provisional Start: 2017-11-13T00:00:00
# Provisional End: 2018-01-27T00:00:00
# Data for chunk 4 of 25 extracted
# Provisional Start: 2018-01-27T00:00:00
# Provisional End: 2018-04-12T00:00:00
# Data for chunk 5 of 25 extracted
# Provisional Start: 2018-04-12T00:00:00
# Provisional End: 2018-06-26T00:00:00
# Data for chunk 6 of 25 extracted
# Provisional Start: 2018-06-26T00:00:00
# Provisional End: 2018-09-09T00:00:00
# Data for chunk 7 of 25 extracted
# Provisional Start: 2018-09-09T00:00:00
# Provisional End: 2018-11-23T00:00:00
# Data for chunk 8 of 25 extracted
# Provisional Start: 2018-11-23T00:00:00
# Provisional End: 2019-02-06T00:00:00
# Data for chunk 9 of 25 extracted
# Provisional Start: 2019-02-06T00:00:00
# Provisional End: 2019-04-22T00:00:00
# Data for chunk 10 of 25 extracted
# Provisional Start: 2019-04-22T00:00:00
# Provisional End: 2019-07-06T00:00:00
# Data for chunk 11 of 25 extracted
# Provisional Start: 2019-07-06T00:00:00
# Provisional End: 2019-09-19T00:00:00
# Data for chunk 12 of 25 extracted
# Provisional Start: 2019-09-19T00:00:00
# Provisional End: 2019-12-03T00:00:00
# Data for chunk 13 of 25 extracted
# Provisional Start: 2019-12-03T00:00:00
# Provisional End: 2020-02-16T00:00:00
# Data for chunk 14 of 25 extracted
# Provisional Start: 2020-02-16T00:00:00
# Provisional End: 2020-05-01T00:00:00
# Data for chunk 15 of 25 extracted
# Provisional Start: 2020-05-01T00:00:00
# Provisional End: 2020-07-15T00:00:00
# Data for chunk 16 of 25 extracted
# Provisional Start: 2020-07-15T00:00:00
# Provisional End: 2020-09-28T00:00:00
# Data for chunk 17 of 25 extracted
# Provisional Start: 2020-09-28T00:00:00
# Provisional End: 2020-12-12T00:00:00
# Data for chunk 18 of 25 extracted
# Provisional Start: 2020-12-12T00:00:00
# Provisional End: 2021-02-25T00:00:00
# Data for chunk 19 of 25 extracted
# Provisional Start: 2021-02-25T00:00:00
# Provisional End: 2021-05-11T00:00:00
# Data for chunk 20 of 25 extracted
# Provisional Start: 2021-05-11T00:00:00
# Provisional End: 2021-07-25T00:00:00
# Data for chunk 21 of 25 extracted
# Provisional Start: 2021-07-25T00:00:00
# Provisional End: 2021-10-08T00:00:00
# Data for chunk 22 of 25 extracted
# Provisional Start: 2021-10-08T00:00:00
# Provisional End: 2021-12-22T00:00:00
# Data for chunk 23 of 25 extracted
# Provisional Start: 2021-12-22T00:00:00
# Provisional End: 2022-03-07T00:00:00
# Data for chunk 24 of 25 extracted
# Provisional Start: 2022-03-07T00:00:00
# Provisional End: 2022-05-21T00:00:00
# Data for chunk 25 of 25 extracted
